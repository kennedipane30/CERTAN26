# %%
# 1. Membaca dataset
import pandas as pd
df = pd.read_csv('Salary_Data.csv')
print(df.head())

# %% [markdown]
# Simple Linear Regression

# %%
# 2. Memisahkan fitur (X) dan target (y)
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
# 1. Membaca dataset berganda
df2 = pd.read_csv('multiple_linear_regression_dataset.csv')
print(df2.head())

# %%
# 3. Visualisasi sebaran data awal
import matplotlib.pyplot as plt
plt.scatter(X, y, color="red")
plt.xlabel('Years Experience')
plt.ylabel('Salary')
plt.show()

# %%
# 4. Membagi dataset menjadi data latih dan data uji
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# 5. Melatih model regresi linear
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
# 6. Menentukan intercept dan slope (persamaan garis)
a = regressor.intercept_
b = regressor.coef_[0]
print("Estimated model intercept, a:", a)
print("Estimated model slope, b:", b)
print(f"y_hat = {a:.2f} + {b:.2f}x")

# %%
# 7. Memprediksi data uji
y_pred = regressor.predict(X_test)
print(y_pred)

# %%
# 8. Mengevaluasi akurasi model
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
print(score)

# %%
# 9. Visualisasi hasil garis regresi pada data latih
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.show()

# %%
# 10. Visualisasi hasil garis regresi pada data uji
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Multiple Linear Regression

# %%
# 2. Memisahkan input (banyak kolom) dan target
X2 = df2.iloc[:, :-1]
y2 = df2.iloc[:, 2]

# %%
# 3. Membagi dataset menjadi data latih dan uji
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=0)

# %%
# 4. Melatih model regresi linier berganda
regressor = LinearRegression()
regressor.fit(X_train2, y_train2)

# %%
# 5. Memprediksi data uji
y_pred2 = regressor.predict(X_test2)
print(y_pred2)

# %%
# 6. Menghitung intercept dan koefisien masing-masing fitur
a_ = regressor.intercept_
b1 = regressor.coef_[0]
b2 = regressor.coef_[1]
print("Estimated model intercept, a:", a_)
print("Estimated model slope, b1:", b1)
print("Estimated model slope, b2:", b2)
print(f"y_hat = {a_:.2f} + {b1:.2f}x1 + {b2:.2f}x2")

# %%
# 7. Evaluasi akurasi model berganda
score2 = r2_score(y_test2, y_pred2)
print(score2)

# %% [markdown]
# TUGAS

# %% [markdown]
# Tugas 1

# %%
df_task1 = pd.read_csv('rounded_hours_student_scores.csv')
print(df_task1.head())

# %%
X_task1 = df_task1.iloc[:, :-1].values
y_task1 = df_task1.iloc[:, 1].values

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_task1, y_task1, test_size=0.2, random_state=0)

# %%
regressor_task1 = LinearRegression()
regressor_task1.fit(X_train1, y_train1)

# %%
a_task1 = regressor_task1.intercept_
b_task1 = regressor_task1.coef_[0]
print("Estimated model intercept, a:", a_task1)
print("Estimated model slope, b:", b_task1)
print(f"y_hat = {a_task1:.2f} + {b_task1:.2f}x")

# %%
y_pred1 = regressor_task1.predict(X_test1)
score1 = r2_score(y_test1, y_pred1)
print("R-Square Score:", score1)

# %%
plt.scatter(X_test1, y_test1, color='red')
plt.plot(X_train1, regressor_task1.predict(X_train1), color='blue')
plt.title('Hours vs Score (Test set)')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# Tugas2

# %%
df_task2 = pd.read_csv('Marketing_Data.csv')
print(df_task2.head())

# %%
X_task2 = df_task2.iloc[:, :-1].values
y_task2 = df_task2.iloc[:, -1].values

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_task2, y_task2, test_size=0.2, random_state=0)

# %%
regressor_task2 = LinearRegression()
regressor_task2.fit(X_train2, y_train2)

# %%
y_pred2 = regressor_task2.predict(X_test2)

# %%
a_task2 = regressor_task2.intercept_
b1 = regressor_task2.coef_[0]
b2 = regressor_task2.coef_[1]
b3 = regressor_task2.coef_[2]

# %%
print("Estimated model intercept, a:", a_task2)
print("Estimated model slope, b1 (youtube):", b1)
print("Estimated model slope, b2 (facebook):", b2)
print("Estimated model slope, b3 (newspaper):", b3)
print(f"y_hat = {a_task2:.2f} + {b1:.2f}x1 + {b2:.2f}x2 + {b3:.2f}x3")

# %%
score2 = r2_score(y_test2, y_pred2)
print("R-Square Score:", score2)
